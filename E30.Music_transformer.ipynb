# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.sequence import pad_sequences

import pandas as pd
import numpy as np

import time
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0" #GPU 1개 == 0
import concurrent.futures

import mido

# %%
# 샘플로 1개의 MIDI 파일을 골라봅니다.
midi_file = os.getenv('HOME')+'/aiffel/music_transformer/data/maestro-v2.0.0/2018/MIDI-Unprocessed_Chamber1_MID--AUDIO_07_R3_2018_wav--2.midi'

midi = mido.MidiFile(midi_file)

# %%
ON = 1
OFF = 0
CC = 2

current_time = 0
eventlist = []
cc = False
for idx, msg in enumerate(midi):
    print('MSG [{}]----------------'.format(idx))
    current_time += msg.time
    print(current_time)
    print(msg.type)
    if msg.type is 'note_on' and msg.velocity > 0:
        event = [current_time, ON, msg.note, msg.velocity]
        print(event)
    elif msg.type is 'note_off' or (msg.type is 'note_on' and msg.velocity == 0):
        event = [current_time, OFF, msg.note, msg.velocity]
        print(event)
        
    if msg.type is 'control_change':
        if msg.control != 64:
            continue
        if cc == False and msg.value > 0:
            cc = True
            event = [current_time, CC, 0, 1]
            print(event)
        elif cc == True and msg.value == 0:
            cc = False
            event = [current_time, CC, 0, 0]
            print(event)

    if idx > 30:
        break
# Out:
# MSG [0]----------------
# 0
# set_tempo
# MSG [1]----------------
# 0
# time_signature
# MSG [2]----------------
# 0
# program_change
# MSG [3]----------------
# 0
# control_change
# MSG [4]----------------
# 0
# control_change
# MSG [5]----------------
# 0.5143229166666666
# control_change
# MSG [6]----------------
# 0.6328125
# control_change
# MSG [7]----------------
# 0.7903645833333333
# control_change
# MSG [8]----------------
# 0.9999999999999999
# control_change
# MSG [9]----------------
# 1.0325520833333333
# note_on
# [1.0325520833333333, 1, 74, 86]
# MSG [10]----------------
# 1.0442708333333333
# note_on
# [1.0442708333333333, 1, 38, 77]
# MSG [11]----------------
# 1.0794270833333333
# control_change
# MSG [12]----------------
# 1.1184895833333333
# control_change
# MSG [13]----------------
# 1.1588541666666665
# control_change
# MSG [14]----------------
# 1.2174479166666665
# control_change
# MSG [15]----------------
# 1.2265624999999998
# note_on
# [1.2265624999999998, 0, 74, 0]
# MSG [16]----------------
# 1.2369791666666665
# control_change
# MSG [17]----------------
# 1.2395833333333333
# note_on
# [1.2395833333333333, 1, 73, 69]
# MSG [18]----------------
# 1.2408854166666665
# note_on
# [1.2408854166666665, 1, 37, 64]
# MSG [19]----------------
# 1.2460937499999998
# note_on
# [1.2460937499999998, 0, 38, 0]
# MSG [20]----------------
# 1.2565104166666665
# control_change
# MSG [21]----------------
# 1.2695312499999998
# note_on
# [1.2695312499999998, 1, 34, 64]
# MSG [22]----------------
# 1.2734374999999998
# note_on
# [1.2734374999999998, 1, 71, 71]
# MSG [23]----------------
# 1.2760416666666665
# control_change
# MSG [24]----------------
# 1.2968749999999998
# control_change
# MSG [25]----------------
# 1.309895833333333
# note_on
# [1.309895833333333, 0, 34, 0]
# MSG [26]----------------
# 1.3164062499999998
# control_change
# MSG [27]----------------
# 1.3164062499999998
# note_on
# [1.3164062499999998, 0, 73, 0]
# MSG [28]----------------
# 1.3242187499999998
# note_on
# [1.3242187499999998, 1, 35, 64]
# MSG [29]----------------
# 1.3242187499999998
# note_on
# [1.3242187499999998, 0, 37, 0]
# MSG [30]----------------
# 1.3359374999999998
# control_change
# MSG [31]----------------
# 1.3437499999999998
# note_on
# [1.3437499999999998, 0, 71, 0]

# %%
IntervalDim = 100

VelocityDim = 32
VelocityOffset = IntervalDim

NoteOnDim = NoteOffDim = 128
NoteOnOffset = IntervalDim + VelocityDim
NoteOffOffset = IntervalDim + VelocityDim + NoteOnDim

CCDim = 2
CCOffset = IntervalDim + VelocityDim + NoteOnDim + NoteOffDim

EventDim = IntervalDim + VelocityDim + NoteOnDim + NoteOffDim + CCDim # 390

def get_data(data, length):    
    # time augmentation
    data[:, 0] *= np.random.uniform(0.80, 1.20)
    
    # absolute time to relative interval
    data[1:, 0] = data[1:, 0] - data[:-1, 0]
    data[0, 0] = 0
    
    # discretize interval into IntervalDim
    data[:, 0] = np.clip(np.round(data[:, 0] * IntervalDim), 0, IntervalDim - 1)
    
    # Note augmentation
    data[:, 2] += np.random.randint(-6, 6)
    data[:, 2] = np.clip(data[:, 2], 0, NoteOnDim - 1)
    
    eventlist = []
    for d in data:
        # append interval
        interval = d[0]
        eventlist.append(interval)
    
        # note on case
        if d[1] == 1:
            velocity = (d[3] / 128) * VelocityDim + VelocityOffset
            note = d[2] + NoteOnOffset
            eventlist.append(velocity)
            eventlist.append(note)
            
        # note off case
        elif d[1] == 0:
            note = d[2] + NoteOffOffset
            eventlist.append(note)
        # CC
        elif d[1] == 2:
            event = CCOffset + d[3]
            eventlist.append(event)
            
    eventlist = np.array(eventlist).astype(np.int)
    
    if len(eventlist) > (length+1):
        start_index = np.random.randint(0, len(eventlist) - (length+1))
        eventlist = eventlist[start_index:start_index+(length+1)]
        
    # pad zeros
    if len(eventlist) < (length+1):
        pad = (length+1) - len(eventlist)
        eventlist = np.pad(eventlist, (pad, 0), 'constant')
        
    x = eventlist[:length]
    y = eventlist[1:length+1]
    
    return x, y

# %%
data_path = os.getenv('HOME')+'/aiffel/music_transformer/data/midi_test.npy'

get_midi = np.load(data_path, allow_pickle=True)
get_midi.shape
# Out:
# (1282,)

# %%
length = 256
train = []
labels = []

for midi_list in get_midi:
    cut_list = [midi_list[i:i+length] for i in range(0, len(midi_list), length)]
    for sublist in cut_list:
        x, y = get_data(np.array(sublist), length)
        train.append(x)
        labels.append(y)

# %%
train = np.array(train)
labels = np.array(labels)

print(train.shape, labels.shape)   # 학습을 위해 MIDI list를 256 길이로 나누었다.
# Out:
# (59268, 256) (59268, 256)

# %%
train_data_pad = pad_sequences(train,
                               maxlen=length,
                               padding='post',
                               value=0)
train_label_pad = pad_sequences(labels,
                                maxlen=length,
                                padding='post',
                                value=0)

# %%
def tensor_casting(train, label):
    train = tf.cast(train, tf.int64)
    label = tf.cast(label, tf.int64)

    return train, label

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((train_data_pad, train_label_pad))
train_dataset = train_dataset.map(tensor_casting)
train_dataset = train_dataset.shuffle(10000).batch(batch_size=16)

# %%
for t,l in train_dataset.take(1):
    print(t)
    print(l)
# Out:
# tf.Tensor(
# [[307   0 328 ... 197   1 121]
#  [  4 316   0 ... 113 210   1]
#  [315   0 389 ...   1 317   0]
#  ...
#  [388   5 300 ... 341   2 109]
#  [331  18 122 ...   1 116 192]
#  [322   1 109 ... 205   3 336]], shape=(16, 256), dtype=int64)
# tf.Tensor(
# [[  0 328  11 ...   1 121 185]
#  [316   0 309 ... 210   1 355]
#  [  0 389   1 ... 317   0 344]
#  ...
#  [  5 300   0 ...   2 109 191]
#  [ 18 122 203 ... 116 192   1]
#  [  1 109 199 ...   3 336   1]], shape=(16, 256), dtype=int64)

# %%
def create_padding_mask(seq):
    seq = tf.cast(tf.math.equal(seq, 1), tf.float32)

    # add extra dimensions to add the padding
    # to the attention logits.
    return seq[:, tf.newaxis, tf.newaxis, :]  # (batch_size, 1, 1, seq_len)


def create_look_ahead_mask(size):
    mask = tf.linalg.band_part(tf.ones((size, size)), -1, 0)
    return mask  # (seq_len, seq_len)


def point_wise_feed_forward_network(d_model, dff):
    return tf.keras.Sequential([
        tf.keras.layers.Dense(dff, activation='relu'),  # (batch_size, seq_len, dff)
        tf.keras.layers.Dense(d_model)  # (batch_size, seq_len, d_model)
    ])

# %%
class RelativeGlobalAttention(tf.keras.layers.Layer):
    def __init__(self, d_model, num_heads):
        super(RelativeGlobalAttention, self).__init__()
        self.num_heads = num_heads
        self.d_model = d_model
        self.headDim = d_model // num_heads
        self.contextDim = int(self.headDim * self.num_heads)
        self.eventDim = 390
        self.E = self.add_weight('E', shape=[self.num_heads, length, self.headDim])

        assert d_model % self.num_heads == 0

        self.wq = tf.keras.layers.Dense(self.headDim)
        self.wk = tf.keras.layers.Dense(self.headDim)
        self.wv = tf.keras.layers.Dense(self.headDim)
    
    def call(self, v, k, q, mask):
        # [Heads, Batch, Time, HeadDim]
        q = tf.stack([self.wq(q) for _ in range(self.num_heads)])
        k = tf.stack([self.wk(k) for _ in range(self.num_heads)])
        v = tf.stack([self.wv(v) for _ in range(self.num_heads)])

        self.batch_size = q.shape[1]
        self.max_len = q.shape[2]
        
        #skewing
        # E = Heads, Time, HeadDim
        # [Heads, Batch * Time, HeadDim]
        Q_ = tf.reshape(q, [self.num_heads, self.batch_size * self.max_len, self.headDim])
        # [Heads, Batch * Time, Time]
        S = tf.matmul(Q_, self.E, transpose_b=True)
        # [Heads, Batch, Time, Time]
        S = tf.reshape(S, [self.num_heads, self.batch_size, self.max_len, self.max_len])
        # [Heads, Batch, Time, Time+1]
        S = tf.pad(S, ((0, 0), (0, 0), (0, 0), (1, 0)))
        # [Heads, Batch, Time+1, Time]
        S = tf.reshape(S, [self.num_heads, self.batch_size, self.max_len + 1, self.max_len])   
        # [Heads, Batch, Time, Time]
        S = S[:, :, 1:]
        # [Heads, Batch, Time, Time]
        attention = (tf.matmul(q, k, transpose_b=True) + S) / np.sqrt(self.headDim)
        # mask tf 2.0 == tf.linalg.band_part
        get_mask = tf.linalg.band_part(tf.ones([self.max_len, self.max_len]), -1, 0)
        attention = attention * get_mask - tf.cast(1e10, attention.dtype) * (1-get_mask)
        score = tf.nn.softmax(attention, axis=3)

        # [Heads, Batch, Time, HeadDim]
        context = tf.matmul(score, v)
        # [Batch, Time, Heads, HeadDim]
        context = tf.transpose(context, [1, 2, 0, 3])
        # [Batch, Time, ContextDim]
        context = tf.reshape(context, [self.batch_size, self.max_len, self.d_model])
        # [Batch, Time, ContextDim]
        logits = tf.keras.layers.Dense(self.d_model)(context)

        return logits, score

# %%
class EncoderLayer(tf.keras.layers.Layer):
    def __init__(self, d_model, num_heads, dff, rate=0.1):
        super(EncoderLayer, self).__init__()

        self.rga = RelativeGlobalAttention(d_model, num_heads)
        self.ffn = point_wise_feed_forward_network(d_model, dff)

        self.layernorm1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)

        self.dropout1 = tf.keras.layers.Dropout(rate)
        self.dropout2 = tf.keras.layers.Dropout(rate)

    def call(self, x, training, mask):
        attn_output, _ = self.rga(x, x, x, mask)  # (batch_size, input_seq_len, d_model)
        attn_output = self.dropout1(attn_output, training=training)
        out1 = self.layernorm1(x + attn_output)  # (batch_size, input_seq_len, d_model)

        ffn_output = self.ffn(out1)  # (batch_size, input_seq_len, d_model)
        ffn_output = self.dropout2(ffn_output, training=training)
        out2 = self.layernorm2(out1 + ffn_output)  # (batch_size, input_seq_len, d_model)

        return out2

# %%
class DecoderLayer(tf.keras.layers.Layer):
    def __init__(self, d_model, num_heads, dff, rate=0.1):
        super(DecoderLayer, self).__init__()

        self.rga1 = RelativeGlobalAttention(d_model, num_heads)
        self.rga2 = RelativeGlobalAttention(d_model, num_heads)

        self.ffn = point_wise_feed_forward_network(d_model, dff)

        self.layernorm1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.layernorm3 = tf.keras.layers.LayerNormalization(epsilon=1e-6)

        self.dropout1 = tf.keras.layers.Dropout(rate)
        self.dropout2 = tf.keras.layers.Dropout(rate)
        self.dropout3 = tf.keras.layers.Dropout(rate)

    def call(self, x, enc_output, training, look_ahead_mask, padding_mask):
        # enc_output.shape == (batch_size, input_seq_len, d_model)

        attn1, attn_weights_block1 = self.rga1(x, x, x, look_ahead_mask)  # (batch_size, target_seq_len, d_model)
        attn1 = self.dropout1(attn1, training=training)
        out1 = self.layernorm1(attn1 + x)

        attn2, attn_weights_block2 = self.rga2(
            enc_output, enc_output, out1, padding_mask)  # (batch_size, target_seq_len, d_model)
        attn2 = self.dropout2(attn2, training=training)
        out2 = self.layernorm2(attn2 + out1)  # (batch_size, target_seq_len, d_model)

        ffn_output = self.ffn(out2)  # (batch_size, target_seq_len, d_model)
        ffn_output = self.dropout3(ffn_output, training=training)
        out3 = self.layernorm3(ffn_output + out2)  # (batch_size, target_seq_len, d_model)

        return out3, attn_weights_block1, attn_weights_block2

# %%
class Encoder(tf.keras.layers.Layer):
    def __init__(self, num_layers, d_model, num_heads, dff, rate=0.1):
        super(Encoder, self).__init__()

        self.num_layers = num_layers
        self.enc_layers = [EncoderLayer(d_model, num_heads, dff, rate) 
                           for _ in range(num_layers)]

        self.dropout = tf.keras.layers.Dropout(rate)

    def call(self, x, training, mask):
        seq_len = tf.shape(x)[1]
        x = self.dropout(x, training=training)

        for i in range(self.num_layers):
            x = self.enc_layers[i](x, training, mask)

        return x  # (batch_size, input_seq_len, d_model)

# %%
class Decoder(tf.keras.layers.Layer):
    def __init__(self, num_layers, d_model, num_heads, dff, rate=0.1):
        super(Decoder, self).__init__()
        self.num_layers = num_layers
        self.dec_layers = [DecoderLayer(d_model, num_heads, dff, rate) 
                           for _ in range(num_layers)]
        self.dropout = tf.keras.layers.Dropout(rate)

    def call(self, x, enc_output, training, look_ahead_mask, padding_mask):
        attention_weights = {}
        x = self.dropout(x, training=training)

        for i in range(self.num_layers):
            x, block1, block2 = self.dec_layers[i](x, enc_output, training,
                                                   look_ahead_mask, padding_mask)

            attention_weights['decoder_layer{}_block1'.format(i+1)] = block1
            attention_weights['decoder_layer{}_block2'.format(i+1)] = block2

        # x.shape == (batch_size, target_seq_len, d_model)
        return x, attention_weights

# %%
class MusicTransformer(tf.keras.Model):
    def __init__(self, num_layers, d_model, num_heads, dff, input_vocab_size, rate=0.1):
        super(MusicTransformer, self).__init__()
        self.d_model = d_model
        self.embedding = tf.keras.layers.Embedding(input_vocab_size, d_model)

        self.encoder = Encoder(num_layers, d_model, num_heads, dff, rate)
        self.decoder = Decoder(num_layers, d_model, num_heads, dff, rate)

        self.final_layer = tf.keras.layers.Dense(input_vocab_size)

    def call(self, inp, training, enc_padding_mask, 
             look_ahead_mask, dec_padding_mask):
        embed = self.embedding(inp)
        embed *= tf.math.sqrt(tf.cast(self.d_model, tf.float32))

        enc_output = self.encoder(embed, training, enc_padding_mask)  # (batch_size, inp_seq_len, d_model)

        # dec_output.shape == (batch_size, tar_seq_len, d_model)
        dec_output, attention_weights = self.decoder(
            embed, enc_output, training, look_ahead_mask, dec_padding_mask)

        final_output = self.final_layer(dec_output)  # (batch_size, tar_seq_len, target_vocab_size)

        return final_output, attention_weights

# %%
num_layers = 4
d_model = 128
dff = 512
num_heads = 8

input_vocab_size = 390   # MIDI가 낼 수 있는 소리의 종류
dropout_rate = 0.1

# %%
# 모델 선언
music_transformer = MusicTransformer(num_layers, d_model, num_heads, dff,
                                     input_vocab_size, rate=dropout_rate)

# %%
class CustomSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, d_model, warmup_steps=4000):
        super(CustomSchedule, self).__init__()

        self.d_model = d_model
        self.d_model = tf.cast(self.d_model, tf.float32)

        self.warmup_steps = warmup_steps

    def __call__(self, step):
        arg1 = tf.math.rsqrt(step)
        arg2 = step * (self.warmup_steps ** -1.5)

        return tf.math.rsqrt(self.d_model) * tf.math.minimum(arg1, arg2)

# %%
learning_rate = CustomSchedule(d_model)

optimizer = tf.keras.optimizers.Adam(learning_rate, beta_1=0.9, beta_2=0.98, 
                                     epsilon=1e-9)

# %%
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')

# %%
def loss_function(real, pred):
    mask = tf.math.logical_not(tf.math.equal(real, 0))
    loss_ = loss_object(real, pred)

    mask = tf.cast(mask, dtype=loss_.dtype)
    loss_ *= mask

    return tf.reduce_sum(loss_)/tf.reduce_sum(mask)

# %%
train_loss = tf.keras.metrics.Mean(name='train_loss')

# %%
checkpoint_path = os.getenv('HOME')+'/aiffel/music_transformer/models/'

ckpt = tf.train.Checkpoint(music_transformer=music_transformer,
                           optimizer=optimizer)

ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=5)

# if a checkpoint exists, restore the latest checkpoint.
if ckpt_manager.latest_checkpoint:
    ckpt.restore(ckpt_manager.latest_checkpoint)
    print ('Latest checkpoint restored!!')
# Out:
# Latest checkpoint restored!!

# %%
#EPOCHS = 20  
EPOCHS = 1  # 1epoch가 매우 오래 걸립니다. 

for epoch in range(EPOCHS):
    start = time.time()

    train_loss.reset_states()

    for (batch, (inp, tar)) in enumerate(train_dataset):
        with tf.GradientTape() as tape:
            predictions, _ = music_transformer(inp, True, None, None, None)
            loss = loss_function(tar, predictions)

        gradients = tape.gradient(loss, music_transformer.trainable_variables)    
        optimizer.apply_gradients(zip(gradients, music_transformer.trainable_variables))

        train_loss(loss)

        if batch % 50 == 0:
            print ('Epoch {} Batch {} Loss {:.4f}'.format(
                epoch + 1, batch, train_loss.result()))

    if (epoch + 1) % 2 == 0:
        ckpt_save_path = ckpt_manager.save()
        print ('Saving checkpoint for epoch {} at {}'.format(epoch+1,
                                                             ckpt_save_path))

    print ('Epoch {} Loss {:.4f}'.format(epoch + 1, train_loss.result()))

    print ('Time taken for 1 epoch: {} secs\n'.format(time.time() - start))
# Out:
# Epoch 1 Batch 0 Loss 3.4156
# Epoch 1 Batch 50 Loss 3.3329
# Epoch 1 Batch 100 Loss 3.3271
# Epoch 1 Batch 150 Loss 3.3288
# Epoch 1 Batch 200 Loss 3.3280
# Epoch 1 Batch 250 Loss 3.3272
# Epoch 1 Batch 300 Loss 3.3257
# Epoch 1 Batch 350 Loss 3.3252
# Epoch 1 Batch 400 Loss 3.3236
# Epoch 1 Batch 450 Loss 3.3243
# Epoch 1 Batch 500 Loss 3.3254
# Epoch 1 Batch 550 Loss 3.3270
# Epoch 1 Batch 600 Loss 3.3267
# Epoch 1 Batch 650 Loss 3.3268
# Epoch 1 Batch 700 Loss 3.3272
# Epoch 1 Batch 750 Loss 3.3269
# Epoch 1 Batch 800 Loss 3.3265
# Epoch 1 Batch 850 Loss 3.3268
# Epoch 1 Batch 900 Loss 3.3271
# Epoch 1 Batch 950 Loss 3.3271
# Epoch 1 Batch 1000 Loss 3.3271
# Epoch 1 Batch 1050 Loss 3.3271
# Epoch 1 Batch 1100 Loss 3.3276
# Epoch 1 Batch 1150 Loss 3.3270
# Epoch 1 Batch 1200 Loss 3.3264
# Epoch 1 Batch 1250 Loss 3.3269
# Epoch 1 Batch 1300 Loss 3.3274
# Epoch 1 Batch 1350 Loss 3.3278
# Epoch 1 Batch 1400 Loss 3.3279
# Epoch 1 Batch 1450 Loss 3.3275
# Epoch 1 Batch 1500 Loss 3.3275
# Epoch 1 Batch 1550 Loss 3.3272
# Epoch 1 Batch 1600 Loss 3.3277
# Epoch 1 Batch 1650 Loss 3.3277
# Epoch 1 Batch 1700 Loss 3.3276
# Epoch 1 Batch 1750 Loss 3.3279
# Epoch 1 Batch 1800 Loss 3.3281
# Epoch 1 Batch 1850 Loss 3.3288
# Epoch 1 Batch 1900 Loss 3.3290
# Epoch 1 Batch 1950 Loss 3.3291
# Epoch 1 Batch 2000 Loss 3.3297
# Epoch 1 Batch 2050 Loss 3.3302
# Epoch 1 Batch 2100 Loss 3.3300
# Epoch 1 Batch 2150 Loss 3.3294
# Epoch 1 Batch 2200 Loss 3.3291
# Epoch 1 Batch 2250 Loss 3.3295
# Epoch 1 Batch 2300 Loss 3.3294
# Epoch 1 Batch 2350 Loss 3.3295
# Epoch 1 Batch 2400 Loss 3.3293
# Epoch 1 Batch 2450 Loss 3.3292
# Epoch 1 Batch 2500 Loss 3.3294
# Epoch 1 Batch 2550 Loss 3.3296
# Epoch 1 Batch 2600 Loss 3.3294
# Epoch 1 Batch 2650 Loss 3.3293
# Epoch 1 Batch 2700 Loss 3.3294
# Epoch 1 Batch 2750 Loss 3.3297
# Epoch 1 Batch 2800 Loss 3.3298
# Epoch 1 Batch 2850 Loss 3.3298
# Epoch 1 Batch 2900 Loss 3.3299
# Epoch 1 Batch 2950 Loss 3.3298
# Epoch 1 Batch 3000 Loss 3.3297
# Epoch 1 Batch 3050 Loss 3.3296
# Epoch 1 Batch 3100 Loss 3.3299
# Epoch 1 Batch 3150 Loss 3.3299
# Epoch 1 Batch 3200 Loss 3.3298
# Epoch 1 Batch 3250 Loss 3.3297
# Epoch 1 Batch 3300 Loss 3.3296
# Epoch 1 Batch 3350 Loss 3.3297
# Epoch 1 Batch 3400 Loss 3.3295
# Epoch 1 Batch 3450 Loss 3.3295
# Epoch 1 Batch 3500 Loss 3.3295
# Epoch 1 Batch 3550 Loss 3.3294
# Epoch 1 Batch 3600 Loss 3.3294
# Epoch 1 Batch 3650 Loss 3.3295
# Epoch 1 Batch 3700 Loss 3.3295
# Epoch 1 Loss 3.3295
# Time taken for 1 epoch: 1135.7775077819824 secs

# %%
tf.train.latest_checkpoint(checkpoint_path)
# Out:
# '/home/aiffel/aiffel/music_transformer/models/ckpt-10'

# %%
test_dataset = tf.data.Dataset.from_tensor_slices((train_data_pad, train_label_pad))
test_dataset = test_dataset.map(tensor_casting)
test_dataset = test_dataset.shuffle(10000).batch(batch_size=1)

# %%
N = 1000
_inputs = np.zeros([1, N], dtype=np.int32)

for x, y in test_dataset.take(1):
    _inputs[:, :length] = x[None, :]
    
for i in range(N - length):
    predictions, _ = music_transformer(_inputs[:, i:i+length], False, None, None, None)
    predictions = tf.squeeze(predictions, 0)    
    
    # select the last word from the seq_len dimension
    predicted_id = tf.random.categorical(predictions, num_samples=1)[-1,0].numpy()
    print(predicted_id)
    
    # 예측된 단어를 다음 입력으로 모델에 전달
    # 이전 은닉 상태와 함께
    _inputs[:, i+length] = predicted_id

_inputs.shape
# Out:
# 112
# 182
# 2
# 342
# 2
# 343
# 3
# 122
# 219
# 5
# 318
# 2
# 327
# 2
# 114
# 202
# 2
# 113
# 182
# 1
# 108
# 188
# 1
# 109
# 188
# 15
# 318
# 1
# 318
# 6
# 315
# 2
# 117
# 206
# 2
# 113
# 190
# 3
# 117
# 209
# 1
# 112
# 193
# 3
# 322
# 1
# 336
# 2
# 318
# 6
# 315
# 4
# 115
# 193
# 3
# 115
# 207
# 5
# 338
# 3
# 314
# 4
# 312
# 7
# 119
# 205
# 2
# 117
# 193
# 3
# 329
# 1
# 332
# 1
# 339
# 1
# 389
# 3
# 303
# 1
# 116
# 203
# 1
# 313
# 1
# 113
# 201
# 1
# 332
# 1
# 333
# 11
# 328
# 3
# 116
# 191
# 2
# 115
# 184
# 1
# 115
# 205
# 1
# 114
# 196
# 5
# 322
# 1
# 333
# 2
# 328
# 4
# 325
# 11
# 122
# 171
# 20
# 318
# 2
# 122
# 202
# 1
# 118
# 187
# 1
# 119
# 206
# 1
# 118
# 206
# 4
# 331
# 3
# 306
# 25
# 121
# 198
# 4
# 325
# 23
# 389
# 1
# 123
# 191
# 2
# 117
# 189
# 4
# 117
# 203
# 3
# 117
# 194
# 11
# 119
# 189
# 2
# 119
# 180
# 2
# 330
# 12
# 121
# 185
# 4
# 288
# 4
# 113
# 182
# 13
# 314
# 23
# 115
# 187
# 1
# 309
# 12
# 121
# 177
# 16
# 113
# 159
# 17
# 311
# 9
# 119
# 178
# 7
# 116
# 194
# 11
# 329
# 1
# 119
# 195
# 3
# 125
# 187
# 13
# 327
# 1
# 319
# 1
# 329
# 20
# 113
# 185
# 1
# 119
# 185
# 2
# 114
# 193
# 4
# 298
# 2
# 116
# 201
# 1
# 327
# 1
# 327
# 3
# 113
# 195
# 4
# 304
# 2
# 111
# 186
# 6
# 292
# 10
# 115
# 179
# 1
# 117
# 179
# 5
# 316
# 1
# 114
# 197
# 9
# 320
# 6
# 116
# 187
# 2
# 326
# 11
# 314
# 9
# 122
# 206
# 6
# 116
# 186
# 21
# 338
# 1
# 120
# 203
# 1
# 309
# 7
# 389
# 19
# 333
# 13
# 114
# 188
# 20
# 124
# 217
# 4
# 348
# 23
# 317
# 11
# 388
# 2
# 116
# 212
# 16
# 124
# 210
# 12
# 335
# 14
# 119
# 196
# 4
# 322
# 3
# 120
# 187
# 3
# 110
# 202
# 3
# 326
# 5
# 330
# 2
# 120
# 190
# 2
# 117
# 199
# 8
# 330
# 1
# 303
# 10
# 121
# 205
# 1
# 113
# 197
# 1
# 330
# 19
# 122
# 217
# 8
# 343
# 15
# 117
# 202
# 2
# 105
# 183
# 1
# 109
# 187
# 9
# 333
# 6
# 331
# 8
# 116
# 205
# 1
# 111
# 192
# 1
# 327
# 2
# 342
# 7
# 114
# 214
# 6
# 342
# 3
# 111
# 203
# 1
# 109
# 193
# 3
# 336
# 5
# 329
# 6
# 108
# 186
# 9
# 117
# 188
# 7
# 314
# 6
# 314
# 1
# 312
# 7
# 112
# 195
# 1
# 111
# 201
# 5
# 323
# 2
# 326
# 4
# 115
# 170
# 1
# 333
# 1
# 112
# 200
# 4
# 388
# 4
# 104
# 199
# 1
# 110
# 188
# 8
# 389
# 4
# 321
# 13
# 325
# 5
# 118
# 205
# 1
# 334
# 1
# 109
# 165
# 3
# 335
# 1
# 111
# 191
# 3
# 306
# 14
# 389
# 20
# 106
# 193
# 6
# 326
# 14
# 329
# 7
# 118
# 197
# 1
# 118
# 198
# 1
# 341
# 3
# 310
# 2
# 115
# 190
# 19
# 325
# 4
# 121
# 196
# 2
# 116
# 196
# 14
# 317
# 5
# 115
# 211
# 1
# 117
# 204
# 7
# 119
# 205
# 15
# 337
# 8
# 306
# 7
# 329
# 1
# 119
# 195
# 2
# 114
# 182
# 4
# 114
# 179
# 6
# 117
# 195
# 22
# 324
# 3
# 327
# 19
# 111
# 191
# 13
# 316
# 3
# 115
# 191
# 2
# 315
# 3
# 317
# 9
# 113
# 194
# 11
# 327
# 2
# 116
# 192
# 1
# 332
# 1
# 110
# 193
# 3
# 308
# 1
# 335
# 2
# 121
# 208
# 5
# 125
# 188
# 2
# 321
# 3
# 327
# 9
# 124
# 179
# 3
# 329
# 4
# 339
# 4
# 322
# 31
# 127
# 178
# 11
# 120
# 197
# 4
# 107
# 189
# 1
# 314
# 3
# 330
# 2
# 317
# 5
# 118
# 211
# 5
# 338
# 3
# 124
# 212
# 3
# 114
# 206
# 7
# 344
# 4
# 122
# 220
# 5
# 108
# 186
# 4
# 340
# 2
# 315
# 1
# 389
# 4
# 117
# 191
# 1
# 113
# 200
# 1
# 336
# 2
# 335
# 1
# 111
# 183
# 1
# 116
# 211
# 1
# 314
# 1
# 346
# 2
# 345
# 10
# 123
# 217
# 4
# 114
# 205
# 4
# 350
# 1
# 111
# 187
# 7
# 332
# 1
# 115
# 194
# 1
# 298
# 1
# 115
# 215
# 8
# 345
# 3
# 116
# 192
# 1
# 117
# 188
# 7
# 327
# 4
# 328
# 9
# 332
# 3
# 117
# 216
# 1
# 114
# 204
# 1
# 113
# 190
# 2
# 109
# 198
# 9
# 321
# 5
# 331
# 1
# 389
# 3
# 332
# 3
# 116
# 186
# 10
# 301
# 4
# 116
# 204
# 2
# 115
# 206
# 1
# 332
# 9
# 388
# 1
# 342
# 5
# 119
# 210
# 15
# 332
# 7
# 120
# 210
# 15
# 348
# 2
# 117
# 196
# 17
# 313
# 2
# 333
# 6
# 121
# 181
# 5
# 327
# 8
# 117
# 189
# 3
# 340
# 1
# 388
# 26
# 309
# 31
# 124
# 200
# 2
# 324
# 4
# 112
# 194
# 4
# 120
# 210
# 10
# 329
# 1
# 113
# 190
# 3
# 331
# 4
# 110
# 191
# 6
# 308
# 2
# 112
# 197
# 4
# 323
# 2
# 115
# 194
# 2
# 318
# 1
# 341
# 1
# 113
# 188
# 4
# 309
# 3
# 327
# 2
# 336
# (1, 1000)

# %%
class Event():
    def __init__(self, time, note, cc, on, velocity):
        self.time = time
        self.note = note
        self.on = on
        self.cc = cc
        self.velocity = velocity

    def get_event_sequence(self):
        return [self.time, self.note, int(self.on)]

class Note():
    def __init__(self):
        self.pitch = 0
        self.start_time = 0
        self.end_time = 0

# %%
event_list = []
time = 0
event = None

EventDim = IntervalDim + VelocityDim + NoteOnDim + NoteOffDim # 388

for _input in _inputs[0]:
    # interval
    if _input < IntervalDim: 
        time += _input
        event = Event(time, 0, False, 0, 0)

    # velocity
    elif _input < NoteOnOffset:
        if event is None:
            continue
        event.velocity = (_input - VelocityOffset) / VelocityDim * 128

    # note on
    elif _input < NoteOffOffset:
        if event is None:
            continue

        event.note = _input - NoteOnOffset
        event.on = True
        event_list.append(event)

        event = None

    # note off
    elif _input < CCOffset:
        if event is None:
            continue
        event.note = _input - NoteOffOffset
        event.on = False
        event_list.append(event)
        event = None

    ## CC
    else:
        if event is None:
            continue
        event.cc = True
        on = _input - CCOffset == 1
        event.on = on
        event_list.append(event)
        event = None

# %%
from mido import Message, MidiFile, MidiTrack, MetaMessage, bpm2tempo

midi = MidiFile()
output_midi_path = os.getenv('HOME')+'/aiffel/music_transformer/data/output_file.mid'

# Instantiate a MIDI Track (contains a list of MIDI events)
track = MidiTrack()
track.append(MetaMessage("set_tempo", tempo=bpm2tempo(120)))
# Append the track to the pattern
midi.tracks.append(track)

prev_time = 0
pitches = [None for _ in range(128)]
for event in event_list:
    tick = (event.time - prev_time) // 3
    midi.ticks_per_beat = 8
    prev_time = event.time

    # case NOTE:
    if not event.cc:
        if event.on:
            if pitches[event.note] is not None:
                # Instantiate a MIDI note off event, append it to the track
                off = Message('note_off', note=event.note, velocity=0, time=0)
                track.append(off)
                pitches[event.note] = None

            # Instantiate a MIDI note on event, append it to the track
            on = Message('note_on', note=event.note, velocity=int(event.velocity), time=tick)
            track.append(on)
            pitches[event.note] = prev_time
        else:
            # Instantiate a MIDI note off event, append it to the track
            off = Message('note_off', note=event.note, velocity=0, time=tick)
            track.append(off)
            pitches[event.note] = None

#     case CC:
    elif event.cc:
        if event.on:
            cc = Message('control_change', control=64, time=tick, value=127)
        else:
            cc = Message('control_change', control=64, time=tick, value=0)

        track.append(cc)

    for pitch in range(128):
        if pitches[pitch] is not None and pitches[pitch] + 100 < prev_time:
            off = Message('note_off', note=pitch, velocity=0, time=0)
            track.append(off)
            pitches[pitch] = None


# Add the end of track event, append it to the track
track.append(MetaMessage("end_of_track"))

# Save the pattern to disk
midi.save(output_midi_path)

for i, track in enumerate(midi.tracks):
    print('Track {}: {}'.format(i, track.name))
    for msg in track:
        print(msg)

print('done')
# Out:
# Track 0:
# <meta message set_tempo tempo=500000 time=0>
# note_off channel=0 note=50 velocity=0 time=0
# note_off channel=0 note=69 velocity=0 time=0
# note_off channel=0 note=60 velocity=0 time=0
# note_off channel=0 note=43 velocity=0 time=0
# note_on channel=0 note=54 velocity=68 time=2
# note_on channel=0 note=45 velocity=52 time=0
# note_on channel=0 note=50 velocity=48 time=0
# note_on channel=0 note=43 velocity=16 time=0
# note_on channel=0 note=62 velocity=76 time=0
# note_on channel=0 note=70 velocity=76 time=0
# note_off channel=0 note=45 velocity=0 time=1
# note_off channel=0 note=54 velocity=0 time=0
# note_off channel=0 note=50 velocity=0 time=0
# note_off channel=0 note=70 velocity=0 time=0
# note_off channel=0 note=62 velocity=0 time=0
# note_off channel=0 note=43 velocity=0 time=0
# control_change channel=0 control=64 value=0 time=0
# note_on channel=0 note=55 velocity=76 time=1
# note_on channel=0 note=43 velocity=52 time=0
# note_on channel=0 note=50 velocity=48 time=0
# control_change channel=0 control=64 value=127 time=0
# note_on channel=0 note=58 velocity=76 time=0
# note_on channel=0 note=67 velocity=72 time=0
# note_off channel=0 note=43 velocity=0 time=0
# note_off channel=0 note=55 velocity=0 time=0
# note_off channel=0 note=50 velocity=0 time=0
# note_off channel=0 note=67 velocity=0 time=0
# note_off channel=0 note=58 velocity=0 time=0
# note_on channel=0 note=55 velocity=76 time=1
# note_on channel=0 note=43 velocity=68 time=0
# note_off channel=0 note=43 velocity=0 time=1
# note_on channel=0 note=62 velocity=64 time=0
# note_on channel=0 note=70 velocity=76 time=0
# note_off channel=0 note=55 velocity=0 time=0
# note_off channel=0 note=62 velocity=0 time=0
# note_off channel=0 note=70 velocity=0 time=0
# note_on channel=0 note=58 velocity=80 time=2
# note_on channel=0 note=55 velocity=68 time=0
# note_off channel=0 note=55 velocity=0 time=1
# note_off channel=0 note=58 velocity=0 time=0
# note_on channel=0 note=67 velocity=48 time=0
# note_on channel=0 note=74 velocity=32 time=0
# note_on channel=0 note=76 velocity=36 time=0
# note_off channel=0 note=67 velocity=0 time=0
# note_off channel=0 note=74 velocity=0 time=0
# note_off channel=0 note=76 velocity=0 time=0
# note_on channel=0 note=58 velocity=72 time=0
# note_on channel=0 note=55 velocity=52 time=0
# note_off channel=0 note=58 velocity=0 time=1
# note_off channel=0 note=55 velocity=0 time=0
# note_on channel=0 note=74 velocity=76 time=0
# note_on channel=0 note=67 velocity=64 time=0
# note_on channel=0 note=70 velocity=44 time=0
# note_off channel=0 note=70 velocity=0 time=1
# note_off channel=0 note=67 velocity=0 time=0
# note_off channel=0 note=74 velocity=0 time=0
# note_on channel=0 note=55 velocity=64 time=1
# note_on channel=0 note=63 velocity=76 time=0
# note_off channel=0 note=63 velocity=0 time=1
# note_off channel=0 note=55 velocity=0 time=0
# note_on channel=0 note=70 velocity=64 time=0
# note_on channel=0 note=74 velocity=72 time=0
# note_on channel=0 note=67 velocity=64 time=0
# note_off channel=0 note=70 velocity=0 time=1
# note_off channel=0 note=67 velocity=0 time=0
# note_off channel=0 note=74 velocity=0 time=0
# note_on channel=0 note=63 velocity=72 time=0
# note_on channel=0 note=55 velocity=56 time=0
# note_off channel=0 note=55 velocity=0 time=1
# note_off channel=0 note=63 velocity=0 time=0
# note_on channel=0 note=67 velocity=60 time=0
# note_on channel=0 note=72 velocity=68 time=0
# note_on channel=0 note=69 velocity=56 time=0
# note_off channel=0 note=67 velocity=0 time=0
# note_off channel=0 note=69 velocity=0 time=0
# note_off channel=0 note=72 velocity=0 time=0
# note_on channel=0 note=63 velocity=68 time=0
# note_on channel=0 note=55 velocity=60 time=0
# note_off channel=0 note=63 velocity=0 time=1
# note_off channel=0 note=55 velocity=0 time=0
# note_on channel=0 note=79 velocity=76 time=0
# note_on channel=0 note=69 velocity=60 time=0
# note_on channel=0 note=72 velocity=52 time=0
# note_off channel=0 note=69 velocity=0 time=0
# note_off channel=0 note=72 velocity=0 time=0
# note_off channel=0 note=79 velocity=0 time=0
# note_on channel=0 note=63 velocity=72 time=0
# note_on channel=0 note=55 velocity=60 time=0
# note_off channel=0 note=55 velocity=0 time=1
# note_off channel=0 note=63 velocity=0 time=0
# note_on channel=0 note=79 velocity=80 time=0
# note_on channel=0 note=72 velocity=60 time=0
# note_on channel=0 note=69 velocity=68 time=0
# note_off channel=0 note=72 velocity=0 time=1
# note_off channel=0 note=69 velocity=0 time=0
# note_on channel=0 note=62 velocity=72 time=0
# note_off channel=0 note=79 velocity=0 time=0
# note_on channel=0 note=57 velocity=56 time=0
# note_on channel=0 note=55 velocity=52 time=0
# note_off channel=0 note=57 velocity=0 time=1
# note_off channel=0 note=62 velocity=0 time=0
# note_off channel=0 note=55 velocity=0 time=0
# note_on channel=0 note=79 velocity=72 time=0
# note_on channel=0 note=50 velocity=48 time=0
# note_off channel=0 note=82 velocity=0 time=0
# note_off channel=0 note=83 velocity=0 time=0
# note_on channel=0 note=87 velocity=88 time=1
# note_off channel=0 note=58 velocity=0 time=1
# note_off channel=0 note=67 velocity=0 time=0
# note_on channel=0 note=70 velocity=56 time=0
# note_off channel=0 note=50 velocity=0 time=0
# note_on channel=0 note=50 velocity=52 time=0
# note_on channel=0 note=56 velocity=32 time=0
# note_off channel=0 note=56 velocity=0 time=0
# note_on channel=0 note=56 velocity=36 time=0
# note_off channel=0 note=58 velocity=0 time=5
# note_off channel=0 note=58 velocity=0 time=0
# note_off channel=0 note=55 velocity=0 time=2
# note_on channel=0 note=74 velocity=68 time=0
# note_on channel=0 note=58 velocity=52 time=0
# note_on channel=0 note=77 velocity=68 time=1
# note_on channel=0 note=61 velocity=48 time=0
# note_off channel=0 note=62 velocity=0 time=1
# note_off channel=0 note=76 velocity=0 time=0
# note_off channel=0 note=58 velocity=0 time=0
# note_off channel=0 note=55 velocity=0 time=2
# note_off channel=0 note=61 velocity=0 time=0
# note_on channel=0 note=61 velocity=60 time=1
# note_on channel=0 note=75 velocity=60 time=1
# note_off channel=0 note=78 velocity=0 time=1
# note_off channel=0 note=54 velocity=0 time=1
# note_off channel=0 note=52 velocity=0 time=1
# note_on channel=0 note=73 velocity=76 time=2
# note_off channel=0 note=61 velocity=0 time=0
# note_on channel=0 note=61 velocity=68 time=0
# note_off channel=0 note=69 velocity=0 time=1
# note_off channel=0 note=72 velocity=0 time=0
# note_off channel=0 note=79 velocity=0 time=0
# control_change channel=0 control=64 value=127 time=0
# note_off channel=0 note=43 velocity=0 time=1
# note_on channel=0 note=71 velocity=64 time=0
# note_off channel=0 note=53 velocity=0 time=0
# note_on channel=0 note=69 velocity=52 time=0
# note_off channel=0 note=72 velocity=0 time=0
# note_off channel=0 note=73 velocity=0 time=0
# note_off channel=0 note=68 velocity=0 time=3
# note_off channel=0 note=87 velocity=0 time=0
# note_on channel=0 note=59 velocity=64 time=1
# note_off channel=0 note=70 velocity=0 time=0
# note_on channel=0 note=52 velocity=60 time=0
# note_off channel=0 note=50 velocity=0 time=0
# note_on channel=0 note=73 velocity=60 time=0
# note_off channel=0 note=56 velocity=0 time=0
# note_on channel=0 note=64 velocity=56 time=0
# note_off channel=0 note=62 velocity=0 time=1
# note_off channel=0 note=73 velocity=0 time=0
# note_off channel=0 note=68 velocity=0 time=0
# note_off channel=0 note=65 velocity=0 time=1
# note_on channel=0 note=39 velocity=88 time=3
# note_off channel=0 note=74 velocity=0 time=0
# note_off channel=0 note=58 velocity=0 time=6
# note_off channel=0 note=77 velocity=0 time=0
# note_on channel=0 note=70 velocity=88 time=0
# note_on channel=0 note=55 velocity=72 time=0
# note_on channel=0 note=74 velocity=76 time=0
# note_off channel=0 note=74 velocity=0 time=0
# note_on channel=0 note=74 velocity=72 time=0
# note_off channel=0 note=75 velocity=0 time=0
# note_off channel=0 note=71 velocity=0 time=1
# note_off channel=0 note=46 velocity=0 time=1
# note_on channel=0 note=66 velocity=84 time=8
# note_off channel=0 note=61 velocity=0 time=0
# note_off channel=0 note=65 velocity=0 time=1
# note_off channel=0 note=69 velocity=0 time=0
# control_change channel=0 control=64 value=127 time=7
# note_off channel=0 note=52 velocity=0 time=0
# note_off channel=0 note=59 velocity=0 time=0
# note_off channel=0 note=64 velocity=0 time=0
# note_on channel=0 note=59 velocity=92 time=0
# note_on channel=0 note=57 velocity=68 time=0
# note_on channel=0 note=71 velocity=68 time=1
# note_on channel=0 note=62 velocity=68 time=1
# note_off channel=0 note=57 velocity=0 time=0
# note_on channel=0 note=57 velocity=76 time=3
# note_off channel=0 note=39 velocity=0 time=0
# note_on channel=0 note=48 velocity=76 time=0
# note_off channel=0 note=70 velocity=0 time=0
# note_on channel=0 note=53 velocity=84 time=4
# note_off channel=0 note=28 velocity=0 time=1
# note_off channel=0 note=55 velocity=0 time=0
# note_on channel=0 note=50 velocity=52 time=1
# note_off channel=0 note=74 velocity=0 time=0
# note_off channel=0 note=54 velocity=0 time=4
# note_on channel=0 note=55 velocity=60 time=7
# note_off channel=0 note=66 velocity=0 time=0
# note_off channel=0 note=49 velocity=0 time=0
# note_on channel=0 note=45 velocity=84 time=4
# note_on channel=0 note=27 velocity=52 time=5
# note_off channel=0 note=59 velocity=0 time=0
# note_off channel=0 note=71 velocity=0 time=0
# note_off channel=0 note=51 velocity=0 time=5
# note_off channel=0 note=48 velocity=0 time=0
# note_off channel=0 note=57 velocity=0 time=0
# note_off channel=0 note=62 velocity=0 time=0
# note_on channel=0 note=46 velocity=76 time=3
# note_on channel=0 note=62 velocity=64 time=2
# note_off channel=0 note=53 velocity=0 time=0
# note_off channel=0 note=69 velocity=0 time=3
# note_off channel=0 note=50 velocity=0 time=0
# note_on channel=0 note=63 velocity=76 time=0
# note_off channel=0 note=55 velocity=0 time=0
# note_on channel=0 note=55 velocity=100 time=1
# note_off channel=0 note=67 velocity=0 time=4
# note_off channel=0 note=59 velocity=0 time=0
# note_off channel=0 note=69 velocity=0 time=0
# note_on channel=0 note=53 velocity=52 time=6
# note_off channel=0 note=53 velocity=0 time=0
# note_on channel=0 note=53 velocity=76 time=0
# note_on channel=0 note=61 velocity=56 time=0
# note_off channel=0 note=45 velocity=0 time=0
# note_off channel=0 note=38 velocity=0 time=1
# note_on channel=0 note=69 velocity=64 time=0
# note_off channel=0 note=67 velocity=0 time=0
# note_off channel=0 note=67 velocity=0 time=0
# note_off channel=0 note=63 velocity=0 time=0
# note_on channel=0 note=63 velocity=52 time=1
# note_off channel=0 note=44 velocity=0 time=1
# note_off channel=0 note=27 velocity=0 time=0
# note_on channel=0 note=54 velocity=44 time=0
# note_off channel=0 note=32 velocity=0 time=2
# note_on channel=0 note=47 velocity=60 time=3
# note_off channel=0 note=47 velocity=0 time=0
# note_on channel=0 note=47 velocity=68 time=0
# note_off channel=0 note=56 velocity=0 time=1
# note_on channel=0 note=65 velocity=56 time=0
# note_off channel=0 note=60 velocity=0 time=3
# note_off channel=0 note=46 velocity=0 time=0
# note_off channel=0 note=62 velocity=0 time=0
# note_off channel=0 note=55 velocity=0 time=0
# note_on channel=0 note=55 velocity=64 time=2
# note_off channel=0 note=66 velocity=0 time=0
# note_off channel=0 note=54 velocity=0 time=3
# note_on channel=0 note=74 velocity=88 time=3
# note_on channel=0 note=54 velocity=64 time=2
# note_off channel=0 note=78 velocity=0 time=7
# note_off channel=0 note=53 velocity=0 time=0
# note_off channel=0 note=61 velocity=0 time=0
# note_on channel=0 note=71 velocity=80 time=0
# note_off channel=0 note=49 velocity=0 time=0
# control_change channel=0 control=64 value=127 time=2
# note_off channel=0 note=63 velocity=0 time=0
# note_off channel=0 note=69 velocity=0 time=0
# note_off channel=0 note=73 velocity=0 time=6
# note_on channel=0 note=56 velocity=56 time=4
# note_off channel=0 note=47 velocity=0 time=0
# note_off channel=0 note=65 velocity=0 time=0
# note_on channel=0 note=85 velocity=96 time=6
# note_off channel=0 note=55 velocity=0 time=0
# note_off channel=0 note=88 velocity=0 time=1
# note_off channel=0 note=57 velocity=0 time=7
# note_off channel=0 note=54 velocity=0 time=0
# note_off channel=0 note=74 velocity=0 time=0
# control_change channel=0 control=64 value=0 time=3
# note_on channel=0 note=80 velocity=64 time=0
# note_on channel=0 note=78 velocity=96 time=5
# note_off channel=0 note=71 velocity=0 time=0
# note_off channel=0 note=75 velocity=0 time=4
# note_on channel=0 note=64 velocity=76 time=4
# note_off channel=0 note=56 velocity=0 time=0
# note_off channel=0 note=62 velocity=0 time=1
# note_on channel=0 note=55 velocity=80 time=1
# note_on channel=0 note=70 velocity=40 time=1
# note_off channel=0 note=66 velocity=0 time=1
# note_off channel=0 note=70 velocity=0 time=1
# note_on channel=0 note=58 velocity=80 time=0
# note_off channel=0 note=85 velocity=0 time=0
# note_on channel=0 note=67 velocity=68 time=0
# note_off channel=0 note=70 velocity=0 time=2
# note_off channel=0 note=43 velocity=0 time=0
# note_on channel=0 note=73 velocity=84 time=3
# note_on channel=0 note=65 velocity=52 time=0
# note_off channel=0 note=70 velocity=0 time=0
# note_on channel=0 note=85 velocity=88 time=6
# note_off channel=0 note=80 velocity=0 time=0
# note_off channel=0 note=83 velocity=0 time=2
# note_on channel=0 note=70 velocity=68 time=5
# note_off channel=0 note=78 velocity=0 time=0
# note_on channel=0 note=51 velocity=20 time=0
# note_off channel=0 note=55 velocity=0 time=0
# note_on channel=0 note=55 velocity=36 time=0
# note_off channel=0 note=73 velocity=0 time=3
# note_off channel=0 note=71 velocity=0 time=2
# note_off channel=0 note=64 velocity=0 time=0
# note_on channel=0 note=73 velocity=64 time=2
# note_on channel=0 note=60 velocity=44 time=0
# note_off channel=0 note=67 velocity=0 time=0
# note_off channel=0 note=82 velocity=0 time=0
# note_on channel=0 note=82 velocity=56 time=2
# note_off channel=0 note=58 velocity=0 time=0
# note_off channel=0 note=82 velocity=0 time=2
# note_on channel=0 note=71 velocity=44 time=1
# note_on channel=0 note=61 velocity=36 time=0
# note_off channel=0 note=76 velocity=0 time=1
# note_off channel=0 note=69 velocity=0 time=1
# note_on channel=0 note=54 velocity=32 time=2
# note_off channel=0 note=65 velocity=0 time=0
# note_on channel=0 note=56 velocity=68 time=3
# note_off channel=0 note=54 velocity=0 time=2
# note_off channel=0 note=54 velocity=0 time=2
# note_off channel=0 note=85 velocity=0 time=0
# note_off channel=0 note=52 velocity=0 time=0
# note_on channel=0 note=63 velocity=48 time=2
# note_on channel=0 note=69 velocity=44 time=0
# note_off channel=0 note=63 velocity=0 time=1
# note_off channel=0 note=66 velocity=0 time=0
# note_on channel=0 note=38 velocity=60 time=1
# note_off channel=0 note=51 velocity=0 time=0
# note_off channel=0 note=70 velocity=0 time=0
# note_off channel=0 note=73 velocity=0 time=0
# note_off channel=0 note=55 velocity=0 time=0
# note_on channel=0 note=68 velocity=48 time=0
# control_change channel=0 control=64 value=0 time=1
# note_on channel=0 note=67 velocity=16 time=1
# note_off channel=0 note=56 velocity=0 time=0
# note_on channel=0 note=56 velocity=40 time=0
# control_change channel=0 control=64 value=127 time=2
# note_off channel=0 note=61 velocity=0 time=1
# note_off channel=0 note=65 velocity=0 time=4
# note_off channel=0 note=60 velocity=0 time=0
# note_on channel=0 note=73 velocity=72 time=1
# note_off channel=0 note=74 velocity=0 time=0
# note_on channel=0 note=33 velocity=36 time=0
# note_off channel=0 note=75 velocity=0 time=1
# note_off channel=0 note=71 velocity=0 time=0
# note_on channel=0 note=59 velocity=44 time=0
# note_off channel=0 note=46 velocity=0 time=1
# control_change channel=0 control=64 value=127 time=4
# note_on channel=0 note=61 velocity=24 time=6
# note_off channel=0 note=66 velocity=0 time=2
# note_off channel=0 note=69 velocity=0 time=0
# note_off channel=0 note=69 velocity=0 time=4
# note_off channel=0 note=38 velocity=0 time=0
# note_off channel=0 note=68 velocity=0 time=0
# note_on channel=0 note=65 velocity=72 time=2
# note_off channel=0 note=67 velocity=0 time=0
# note_on channel=0 note=66 velocity=72 time=0
# note_off channel=0 note=56 velocity=0 time=0
# note_off channel=0 note=81 velocity=0 time=0
# note_off channel=0 note=50 velocity=0 time=1
# note_on channel=0 note=58 velocity=60 time=0
# note_off channel=0 note=65 velocity=0 time=6
# note_on channel=0 note=64 velocity=84 time=1
# note_off channel=0 note=64 velocity=0 time=0
# note_on channel=0 note=64 velocity=64 time=0
# note_off channel=0 note=73 velocity=0 time=0
# note_off channel=0 note=57 velocity=0 time=4
# note_off channel=0 note=33 velocity=0 time=0
# note_off channel=0 note=59 velocity=0 time=0
# note_on channel=0 note=79 velocity=60 time=1
# note_on channel=0 note=72 velocity=68 time=0
# note_on channel=0 note=73 velocity=76 time=2
# note_off channel=0 note=77 velocity=0 time=5
# note_off channel=0 note=61 velocity=0 time=0
# note_off channel=0 note=46 velocity=0 time=2
# note_off channel=0 note=69 velocity=0 time=2
# note_on channel=0 note=63 velocity=76 time=0
# note_on channel=0 note=50 velocity=56 time=0
# note_on channel=0 note=47 velocity=56 time=1
# note_off channel=0 note=63 velocity=0 time=0
# note_on channel=0 note=63 velocity=68 time=2
# note_off channel=0 note=66 velocity=0 time=0
# note_off channel=0 note=64 velocity=0 time=7
# note_off channel=0 note=58 velocity=0 time=0
# note_off channel=0 note=67 velocity=0 time=1
# note_on channel=0 note=59 velocity=44 time=6
# note_off channel=0 note=56 velocity=0 time=4
# note_off channel=0 note=72 velocity=0 time=0
# note_off channel=0 note=79 velocity=0 time=0
# note_off channel=0 note=59 velocity=0 time=0
# note_on channel=0 note=59 velocity=60 time=1
# note_off channel=0 note=73 velocity=0 time=0
# note_off channel=0 note=55 velocity=0 time=0
# note_off channel=0 note=57 velocity=0 time=1
# note_on channel=0 note=62 velocity=52 time=3
# note_off channel=0 note=67 velocity=0 time=3
# note_on channel=0 note=60 velocity=64 time=0
# note_off channel=0 note=72 velocity=0 time=0
# note_on channel=0 note=61 velocity=40 time=0
# note_off channel=0 note=48 velocity=0 time=1
# note_off channel=0 note=50 velocity=0 time=0
# note_off channel=0 note=75 velocity=0 time=0
# note_on channel=0 note=76 velocity=84 time=0
# note_off channel=0 note=47 velocity=0 time=0
# note_on channel=0 note=56 velocity=100 time=1
# note_off channel=0 note=61 velocity=0 time=0
# note_off channel=0 note=63 velocity=0 time=0
# note_off channel=0 note=67 velocity=0 time=1
# note_on channel=0 note=47 velocity=96 time=3
# note_off channel=0 note=69 velocity=0 time=1
# note_off channel=0 note=79 velocity=0 time=1
# note_off channel=0 note=62 velocity=0 time=1
# note_on channel=0 note=46 velocity=108 time=10
# note_on channel=0 note=65 velocity=80 time=3
# note_off channel=0 note=59 velocity=0 time=0
# note_on channel=0 note=57 velocity=28 time=1
# note_off channel=0 note=54 velocity=0 time=0
# note_off channel=0 note=70 velocity=0 time=1
# note_off channel=0 note=57 velocity=0 time=0
# note_on channel=0 note=79 velocity=72 time=1
# note_off channel=0 note=78 velocity=0 time=1
# note_on channel=0 note=80 velocity=96 time=1
# note_off channel=0 note=60 velocity=0 time=0
# note_on channel=0 note=74 velocity=56 time=1
# note_off channel=0 note=84 velocity=0 time=2
# note_off channel=0 note=76 velocity=0 time=0
# note_on channel=0 note=88 velocity=88 time=1
# note_off channel=0 note=56 velocity=0 time=0
# note_on channel=0 note=54 velocity=32 time=1
# note_off channel=0 note=80 velocity=0 time=1
# note_off channel=0 note=55 velocity=0 time=0
# note_off channel=0 note=47 velocity=0 time=0
# control_change channel=0 control=64 value=127 time=0
# note_on channel=0 note=59 velocity=68 time=1
# note_on channel=0 note=68 velocity=52 time=0
# note_off channel=0 note=76 velocity=0 time=0
# note_off channel=0 note=75 velocity=0 time=0
# note_on channel=0 note=51 velocity=44 time=0
# note_off channel=0 note=79 velocity=0 time=0
# note_on channel=0 note=79 velocity=64 time=0
# note_off channel=0 note=54 velocity=0 time=0
# note_off channel=0 note=86 velocity=0 time=0
# note_off channel=0 note=85 velocity=0 time=0
# note_on channel=0 note=85 velocity=92 time=3
# note_on channel=0 note=73 velocity=56 time=1
# note_off channel=0 note=90 velocity=0 time=1
# note_on channel=0 note=55 velocity=44 time=0
# note_off channel=0 note=72 velocity=0 time=2
# note_on channel=0 note=62 velocity=60 time=0
# note_off channel=0 note=46 velocity=0 time=0
# note_off channel=0 note=38 velocity=0 time=0
# note_on channel=0 note=83 velocity=60 time=0
# note_off channel=0 note=85 velocity=0 time=2
# note_on channel=0 note=60 velocity=64 time=1
# note_off channel=0 note=65 velocity=0 time=0
# note_on channel=0 note=56 velocity=68 time=0
# note_off channel=0 note=67 velocity=0 time=2
# note_off channel=0 note=68 velocity=0 time=1
# note_off channel=0 note=72 velocity=0 time=3
# note_on channel=0 note=84 velocity=68 time=1
# note_off channel=0 note=74 velocity=0 time=0
# note_on channel=0 note=72 velocity=56 time=0
# note_on channel=0 note=58 velocity=52 time=0
# note_on channel=0 note=66 velocity=36 time=0
# note_off channel=0 note=61 velocity=0 time=3
# note_off channel=0 note=88 velocity=0 time=0
# note_off channel=0 note=71 velocity=0 time=1
# control_change channel=0 control=64 value=127 time=0
# note_off channel=0 note=72 velocity=0 time=1
# note_on channel=0 note=54 velocity=64 time=1
# note_off channel=0 note=41 velocity=0 time=3
# note_off channel=0 note=51 velocity=0 time=0
# note_off channel=0 note=59 velocity=0 time=0
# note_off channel=0 note=79 velocity=0 time=0
# note_on channel=0 note=72 velocity=64 time=1
# note_on channel=0 note=74 velocity=60 time=0
# note_off channel=0 note=72 velocity=0 time=0
# control_change channel=0 control=64 value=0 time=3
# note_off channel=0 note=73 velocity=0 time=0
# note_off channel=0 note=82 velocity=0 time=0
# note_on channel=0 note=78 velocity=76 time=1
# note_off channel=0 note=55 velocity=0 time=0
# note_off channel=0 note=72 velocity=0 time=5
# note_off channel=0 note=62 velocity=0 time=0
# note_off channel=0 note=83 velocity=0 time=0
# note_off channel=0 note=78 velocity=0 time=0
# note_on channel=0 note=78 velocity=80 time=2
# note_off channel=0 note=56 velocity=0 time=0
# note_off channel=0 note=60 velocity=0 time=0
# note_off channel=0 note=88 velocity=0 time=5
# note_on channel=0 note=64 velocity=68 time=0
# note_off channel=0 note=53 velocity=0 time=5
# note_off channel=0 note=58 velocity=0 time=0
# note_off channel=0 note=66 velocity=0 time=0
# note_off channel=0 note=84 velocity=0 time=0
# note_off channel=0 note=73 velocity=0 time=0
# note_on channel=0 note=49 velocity=84 time=2
# note_off channel=0 note=67 velocity=0 time=1
# note_off channel=0 note=54 velocity=0 time=0
# note_on channel=0 note=57 velocity=68 time=2
# note_off channel=0 note=80 velocity=0 time=1
# control_change channel=0 control=64 value=0 time=0
# note_off channel=0 note=49 velocity=0 time=8
# note_off channel=0 note=74 velocity=0 time=0
# note_on channel=0 note=68 velocity=96 time=10
# note_off channel=0 note=78 velocity=0 time=0
# note_off channel=0 note=64 velocity=0 time=0
# note_on channel=0 note=62 velocity=48 time=1
# note_on channel=0 note=78 velocity=80 time=1
# note_off channel=0 note=69 velocity=0 time=3
# note_on channel=0 note=58 velocity=52 time=0
# note_off channel=0 note=71 velocity=0 time=1
# note_on channel=0 note=59 velocity=40 time=1
# note_off channel=0 note=48 velocity=0 time=2
# note_on channel=0 note=65 velocity=48 time=0
# note_off channel=0 note=63 velocity=0 time=1
# note_off channel=0 note=57 velocity=0 time=0
# note_off channel=0 note=62 velocity=0 time=0
# note_on channel=0 note=62 velocity=60 time=0
# note_off channel=0 note=58 velocity=0 time=0
# note_off channel=0 note=81 velocity=0 time=0
# note_on channel=0 note=56 velocity=52 time=0
# note_off channel=0 note=49 velocity=0 time=1
# note_off channel=0 note=67 velocity=0 time=1
# note_off channel=0 note=76 velocity=0 time=0
# <meta message end_of_track time=0>
# done
